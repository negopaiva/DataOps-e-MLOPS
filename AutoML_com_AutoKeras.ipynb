# %% [markdown]
# # **AutoML com AutoKeras**
# - O Automated Machine Learning é também conhecido como AutoML;
# - Ferramentas e serviços que abstraem os detalhes e conhecimentos necessários para se realizar ML/DL;
# - Automatiza-se determinadas tarefas necessárias no desenvolvimento de algum modelo;
# - Geralmente, cobrem etapas de normalização de dados e engenharia de “features”; treinamento de modelos de diferentes tipos e com diferentes hiperparâmetros; avaliação e comparação de resultados;
# - Algumas ferramentas: H2O, AutoKeras e TPOT;
#
# - Vantagens:
#   - Necessário conhecimento superficial de ML/DL para se utilizar as ferramentas;
#   - Diminui o tempo para se ter resultados iniciais;
#   - Pode-se utilizar em diferentes tipos de dados e problemas (baseline);
#   - Algumas ferramentas possibilitam customizar modelos/layers;
# - Desvantagens:
#   - Customização que pode ser limitada ou dificultada;
#   - Pode-se não obter resultado bom o bastante para o problema, precisando da intervenção de especialistas;

# %% [markdown]
# ##**Instalação da biblioteca AutoKeras**

# %%
# %%capture
# !pip install autokeras

# %% [markdown]
# ##**Import dos pacotes necessários**

# %%
import os
import sklearn
import tensorflow
import pandas as pd
import autokeras as ak

from tensorflow import keras
from keras import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# ##**Cópia do dataset**

# %%
# %%time
# !rm -r lectures-cdas-2023
# !git clone https://github.com/renansantosmendes/lectures-cdas-2023.git
# Out:
# 'rm' n�o � reconhecido como um comando interno
# ou externo, um programa oper�vel ou um arquivo em lotes.
# CPU times: total: 78.1 ms
# Wall time: 3.17 s
# Cloning into 'lectures-cdas-2023'...

# %% [markdown]
# ##**Leitura do dataset em um DataFrame do Pandas**

# %%
data = pd.read_csv(os.path.join('lectures-cdas-2023', 'fetal_health.csv'))

# %% [markdown]
# ##**Processamento dos dados**
# Nesta célula serão feitos os seguintes passos:
# - Separação das variáveis de entrada e saída
# - Padronização dos valores das variáveis de entrada
# - Separação em dados de treino e teste
# - Categorização dos dados de saída (a serem preditos)

# %%
X=data.drop(["fetal_health"], axis=1)
y=data["fetal_health"]

columns_names = list(X.columns)
X_df = StandardScaler().fit_transform(X)
X_df = pd.DataFrame(X_df, columns=columns_names)

X_train, X_test, y_train, y_test = train_test_split(X_df, y, test_size=0.3, random_state=42)
y_train=keras.utils.to_categorical(y_train)[:,1:]
y_test=keras.utils.to_categorical(y_test)[:,1:]

# %% [markdown]
# ##**Criação do modelo (atualizado)**
# A partir da versão 2.0.0 do AutoKeras a classe StructuredDataClassifier foi descontinuada e uma forma de contornar é por meio do uso da classe AutoModel em conjunto com a ClassificationHead. Dessa forma o modelo poderá ser treinado conforme o código abaixo

# %%
# %%time
input_node = ak.Input()
output_node = ak.ClassificationHead(num_classes=3)(input_node)
auto_model = ak.AutoModel(inputs=input_node,
                          outputs=output_node,
                          max_trials=10,
                          overwrite=True)

auto_model.fit(X_train.values, y_train, epochs=10)
# Out:
# WARNING:tensorflow:From c:\Users\ander\anaconda3\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# CPU times: total: 2.64 s
# Wall time: 4.27 s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', 'input_node = ak.Input()\noutput_node = ak.ClassificationHead(num_classes=3)(input_node)\nauto_model = ak.AutoModel(inputs=input_node,\n                          outputs=output_node,\n                          max_trials=10,\n                          overwrite=True)\n\nauto_model.fit(X_train.values, y_train, epochs=10)\n')
#
# File c:\Users\ander\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\ander\anaconda3\Lib\site-packages\IPython\core\magics\execution.py:1452, in ExecutionMagics.time(self, line, cell, local_ns)
#    1450 if interrupt_occured:
#    1451     if exit_on_interrupt and captured_exception:
# -> 1452         raise captured_exception
#    1453     return
#    1454 return out
#
# File c:\Users\ander\anaconda3\Lib\site-packages\IPython\core\magics\execution.py:1421, in ExecutionMagics.time(self, line, cell, local_ns)
#    1419     if expr_val is not None:
#    1420         code_2 = self.shell.compile(expr_val, source, 'eval')
# -> 1421         out = eval(code_2, glob, local_ns)
#    1422 except KeyboardInterrupt as e:
#    1423     captured_exception = e
#
# File <timed exec>:8
#
# File c:\Users\ander\anaconda3\Lib\site-packages\autokeras\auto_model.py:303, in AutoModel.fit(self, x, y, batch_size, epochs, callbacks, validation_split, validation_data, verbose, **kwargs)
#     298     dataset, validation_data = data_utils.split_dataset(
#     299         dataset, validation_split
#     300     )
#     302 x, y = dataset
# --> 303 history = self.tuner.search(
#     304     x=x,
#     305     y=y,
#     306     epochs=epochs,
#     307     callbacks=callbacks,
#     308     validation_data=validation_data,
#     309     validation_split=validation_split,
#     310     verbose=verbose,
#     311     batch_size=batch_size,
#     312     **kwargs
#     313 )
#     315 return history
#
# File c:\Users\ander\anaconda3\Lib\site-packages\autokeras\engine\tuner.py:204, in AutoTuner.search(self, epochs, callbacks, validation_split, verbose, **fit_kwargs)
#     202 hp = self.oracle.get_space()
#     203 self._prepare_model_build(hp, **fit_kwargs)
# --> 204 self._try_build(hp)
#     205 self.oracle.update_space(hp)
#     206 super().search(
#     207     epochs=epochs,
#     208     callbacks=new_callbacks,
#     209     verbose=verbose,
#     210     **fit_kwargs
#     211 )
#
# File c:\Users\ander\anaconda3\Lib\site-packages\keras_tuner\src\engine\tuner.py:164, in Tuner._try_build(self, hp)
#     161 keras.backend.clear_session()
#     162 gc.collect()
# --> 164 model = self._build_hypermodel(hp)
#     165 # Stop if `build()` does not return a valid model.
#     166 if not isinstance(model, keras.models.Model):
#
# File c:\Users\ander\anaconda3\Lib\site-packages\keras_tuner\src\engine\tuner.py:155, in Tuner._build_hypermodel(self, hp)
#     153 def _build_hypermodel(self, hp):
#     154     with maybe_distribute(self.distribution_strategy):
# --> 155         model = self.hypermodel.build(hp)
#     156         self._override_compile_args(model)
#     157         return model
#
# File c:\Users\ander\anaconda3\Lib\site-packages\keras_tuner\src\engine\hypermodel.py:120, in HyperModel._build_wrapper(self, hp, *args, **kwargs)
#     116 if not self.tunable:
#     117     # Copy `HyperParameters` object so that new entries are not added
#     118     # to the search space.
#     119     hp = hp.copy()
# --> 120 return self._build(hp, *args, **kwargs)
#
# File c:\Users\ander\anaconda3\Lib\site-packages\autokeras\graph.py:251, in Graph.build(self, hp)
#     246 for block in self.blocks:
#     247     temp_inputs = [
#     248         keras_nodes[self._node_to_id[input_node]]
#     249         for input_node in block.inputs
#     250     ]
# --> 251     outputs = block.build(hp, inputs=temp_inputs)
#     252     outputs = tree.flatten(outputs)
#     253     for output_node, real_output_node in zip(block.outputs, outputs):
#
# File c:\Users\ander\anaconda3\Lib\site-packages\autokeras\engine\block.py:38, in Block._build_wrapper(self, hp, *args, **kwargs)
#      36 def _build_wrapper(self, hp, *args, **kwargs):
#      37     with hp.name_scope(self.name):
# ---> 38         return super()._build_wrapper(hp, *args, **kwargs)
#
# File c:\Users\ander\anaconda3\Lib\site-packages\keras_tuner\src\engine\hypermodel.py:120, in HyperModel._build_wrapper(self, hp, *args, **kwargs)
#     116 if not self.tunable:
#     117     # Copy `HyperParameters` object so that new entries are not added
#     118     # to the search space.
#     119     hp = hp.copy()
# --> 120 return self._build(hp, *args, **kwargs)
#
# File c:\Users\ander\anaconda3\Lib\site-packages\autokeras\blocks\heads.py:119, in ClassificationHead.build(self, hp, inputs)
#     117 if dropout > 0:
#     118     output_node = layers.Dropout(dropout)(output_node)
# --> 119 output_node = layers.Dense(self.shape[-1])(output_node)
#     120 if isinstance(self.loss, keras.losses.BinaryCrossentropy):
#     121     output_node = layers.Activation(
#     122         activations.sigmoid, name=self.name
#     123     )(output_node)
#
# File c:\Users\ander\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:101, in Dense.__init__(self, units, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, lora_rank, lora_alpha, quantization_config, **kwargs)
#      83 def __init__(
#      84     self,
#      85     units,
#    (...)     98     **kwargs,
#      99 ):
#     100     if not isinstance(units, int) or units <= 0:
# --> 101         raise ValueError(
#     102             "Received an invalid value for `units`, expected a positive "
#     103             f"integer. Received: units={units}"
#     104         )
#     106     super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#     107     self.units = units
#
# ValueError: Received an invalid value for `units`, expected a positive integer. Received: units=3

# %% [markdown]
# ##**Exportando o melhor modelo encontrado até o momento**

# %%
model = auto_model.export_model()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 model = auto_model.export_model()
#
# File c:\Users\ander\anaconda3\Lib\site-packages\autokeras\auto_model.py:481, in AutoModel.export_model(self)
#     474 def export_model(self):
#     475     """Export the best Keras Model.
#     476
#     477     # Returns
#     478         keras.Model instance. The best model found during the search, loaded
#     479         with trained weights.
#     480     """
# --> 481     return self.tuner.get_best_model()
#
# File c:\Users\ander\anaconda3\Lib\site-packages\autokeras\engine\tuner.py:66, in AutoTuner.get_best_model(self)
#      65 def get_best_model(self):
# ---> 66     return self.get_best_models()[0]
#
# IndexError: list index out of range

# %% [markdown]
# ##**Vendo o resumo do melhor modelo**

# %%
model.summary()

# %% [markdown]
# ##**Avaliando o modelo encontrado com os dados de teste**

# %%
model.evaluate(X_test, y_test)
