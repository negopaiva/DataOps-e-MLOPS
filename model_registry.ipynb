# %% [markdown]
# ## Instalando o MLflow

# %%
# %%capture
# !pip install mlflow -q

# %% [markdown]
# ## import das bibliotecas

# %%
import os
import mlflow
import numpy as np

# %% [markdown]
# ## Configurando o MLflow

# %%
MLFLOW_TRACKING_URI = ''
MLFLOW_TRACKING_USERNAME = ''
MLFLOW_TRACKING_PASSWORD = ''
os.environ['MLFLOW_TRACKING_USERNAME'] = negopaiva
os.environ['MLFLOW_TRACKING_PASSWORD'] = Paiva141519

mlflow.set_tracking_uri(https://dagshub.com/negopaiva/DataOps-e-MLOPS)
# Out:
#   Cell In[11], line 7
#     mlflow.set_tracking_uri(https://dagshub.com/negopaiva/DataOps-e-MLOPS)
#                                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Criando um client para comunicar com o registro no DagsHub

# %%
client = mlflow.MlflowClient(tracking_uri=MLFLOW_TRACKING_URI)
# Out:
# c:\Users\ander\anaconda3\Lib\site-packages\mlflow\tracking\_tracking_service\utils.py:184: FutureWarning: The filesystem tracking backend (e.g., './mlruns') is deprecated as of February 2026. Consider transitioning to a database backend (e.g., 'sqlite:///mlflow.db') to take advantage of the latest MLflow features. See https://mlflow.org/docs/latest/self-hosting/migrate-from-file-store for migration guidance.
#   return FileStore(store_uri, store_uri)

# %%
client

# %% [markdown]
# ## Recebendo o modelo registrado e suas versões

# %%
registered_model = client.get_registered_model('fetal_health')
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 registered_model = client.get_registered_model('fetal_health')
#
# File c:\Users\ander\anaconda3\Lib\site-packages\mlflow\tracking\client.py:4301, in MlflowClient.get_registered_model(self, name)
#    4260 def get_registered_model(self, name: str) -> RegisteredModel:
#    4261     """Get a registered model.
#    4262
#    4263     Args:
#    (...)   4299         description: This sentiment analysis model classifies the tone-happy, sad, angry.
#    4300     """
# -> 4301     rm = self._get_registry_client().get_registered_model(name)
#    4303     # Prompt should not be returned as a registered model
#    4304     if has_prompt_tag(rm._tags):
#
# File c:\Users\ander\anaconda3\Lib\site-packages\mlflow\tracking\_model_registry\client.py:181, in ModelRegistryClient.get_registered_model(self, name)
#     173 def get_registered_model(self, name):
#     174     """
#     175     Args:
#     176         name: Name of the registered model to get.
#    (...)    179         A single :py:class:`mlflow.entities.model_registry.RegisteredModel` object.
#     180     """
# --> 181     return self.store.get_registered_model(name)
#
# File c:\Users\ander\anaconda3\Lib\site-packages\mlflow\store\model_registry\file_store.py:431, in FileStore.get_registered_model(self, name)
#     429 model_path = self._get_registered_model_path(name)
#     430 if not exists(model_path):
# --> 431     raise MlflowException(
#     432         f"Registered Model with name={name} not found",
#     433         RESOURCE_DOES_NOT_EXIST,
#     434     )
#     435 return self._get_registered_model_from_path(model_path)
#
# MlflowException: Registered Model with name=fetal_health not found

# %%
registered_model.latest_versions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 registered_model.latest_versions
#
# NameError: name 'registered_model' is not defined

# %% [markdown]
# ## Obtendo o id da execução do modelo

# %%
run_id = registered_model.latest_versions[-1].run_id

# %% [markdown]
# ## Carregando o modelo

# %%
logged_model = f'runs:/{run_id}/model'
loaded_model = mlflow.pyfunc.load_model(logged_model)

# %% [markdown]
# ## Fazendo uma predição com o modelo carregadO

# %%
accelerations = 0
fetal_movement = 0
uterine_contractions = 0
severe_decelerations = 0

# %%
received_data = np.array([
        accelerations,
        fetal_movement,
        uterine_contractions,
        severe_decelerations,
    ]).reshape(1, -1)

# %%
received_data

# %%
loaded_model.predict(received_data)
