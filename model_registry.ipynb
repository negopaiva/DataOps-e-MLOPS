# %% [markdown]
# ## Instalando o MLflow

# %%
# %%capture
# !pip install mlflow -q

# %% [markdown]
# ## import das bibliotecas

# %%
import os
import mlflow
import numpy as np

# %% [markdown]
# ## Configurando o MLflow

# %%
MLFLOW_TRACKING_URI = 'https://dagshub.com/negopaiva/DataOps-e-MLOPS.mlflow'
MLFLOW_TRACKING_USERNAME = 'negopaiva'
MLFLOW_TRACKING_PASSWORD = 'd7da0c3c6de5b2c1455749b3a2794b713c2a36a5'
os.environ['MLFLOW_TRACKING_USERNAME'] = MLFLOW_TRACKING_USERNAME
os.environ['MLFLOW_TRACKING_PASSWORD'] = MLFLOW_TRACKING_PASSWORD

mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

# %% [markdown]
# ## Criando um client para comunicar com o registro no DagsHub

# %%
client = mlflow.MlflowClient(tracking_uri=MLFLOW_TRACKING_URI)

# %%
client

# %% [markdown]
# ## Recebendo o modelo registrado e suas versões

# %%
registered_model = client.get_registered_model('fetal_health')

# %%
registered_model.latest_versions
# Out:
# [<ModelVersion: aliases=[], creation_timestamp=1774794579537, current_stage='None', deployment_job_state=<ModelVersionDeploymentJobState: current_task_name='', job_id='', job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', run_id='', run_state='DEPLOYMENT_JOB_RUN_STATE_UNSPECIFIED'>, description='', last_updated_timestamp=1774794579537, metrics=None, model_id=None, name='fetal_health', params=None, run_id='337b6c57136d499dbef12040e6d3ebab', run_link='', source='mlflow-artifacts:/2585239fde4c45c9a28d80756c05959c/337b6c57136d499dbef12040e6d3ebab/artifacts', status='READY', status_message=None, tags={}, user_id='', version='3', workspace='default'>]

# %% [markdown]
# ## Obtendo o id da execução do modelo

# %%
run_id = registered_model.latest_versions[-1].run_id

# %% [markdown]
# ## Carregando o modelo

# %%
logged_model = f'runs:/{run_id}/model'
loaded_model = mlflow.pyfunc.load_model(logged_model)
# Out:
# Downloading artifacts:   0%|          | 0/6 [00:00<?, ?it/s]
# 2026/03/29 11:34:28 WARNING mlflow.utils.requirements_utils: Detected one or more mismatches between the model's dependencies and the current Python environment:
#  - mlflow (current: 3.10.1, required: mlflow==2.22.1)
#  - keras (current: 3.13.2, required: keras==3.12.1)
#  - numpy (current: 2.3.5, required: numpy==2.0.2)
#  - tensorflow (current: 2.21.0, required: tensorflow==2.18.0)
# To fix the mismatches, call `mlflow.pyfunc.get_model_dependencies(model_uri)` to fetch the model's environment and install dependencies using the resulting environment file.
# 2026/03/29 11:34:28 WARNING mlflow.pyfunc: The version of Python that the model was saved in, `Python 3.10.20`, differs from the version of Python that is currently running, `Python 3.13.9`, and may be incompatible
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# ## Fazendo uma predição com o modelo carregadO

# %%
accelerations = 0
fetal_movement = 0
uterine_contractions = 0
severe_decelerations = 0

# %%
received_data = np.array([
        accelerations,
        fetal_movement,
        uterine_contractions,
        severe_decelerations,
    ]).reshape(1, -1)

# %%
received_data
# Out:
# array([[0, 0, 0, 0]])

# %%
loaded_model.predict(received_data)
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# File c:\Users\ander\anaconda3\Lib\site-packages\mlflow\pyfunc\__init__.py:732, in _validate_prediction_input(data, params, input_schema, params_schema, flavor)
#     731 try:
# --> 732     data = _enforce_schema(data, input_schema, flavor)
#     733 except Exception as e:
#
# File c:\Users\ander\anaconda3\Lib\site-packages\mlflow\models\utils.py:1275, in _enforce_schema(pf_input, input_schema, flavor)
#    1274 if input_schema.is_tensor_spec():
# -> 1275     return _enforce_tensor_schema(pf_input, input_schema)
#    1276 elif HAS_PYSPARK and isinstance(original_pf_input, SparkDataFrame):
#
# File c:\Users\ander\anaconda3\Lib\site-packages\mlflow\models\utils.py:1117, in _enforce_tensor_schema(pf_input, input_schema)
#    1116 elif isinstance(pf_input, np.ndarray) or _is_sparse_matrix(pf_input):
# -> 1117     new_pf_input = _enforce_tensor_spec(pf_input, tensor_spec)
#    1118 else:
#
# File c:\Users\ander\anaconda3\Lib\site-packages\mlflow\models\utils.py:734, in _enforce_tensor_spec(values, tensor_spec)
#     733 if clean_tensor_type(actual_type) != expected_type:
# --> 734     raise MlflowException(
#     735         f"dtype of input {actual_type} does not match expected dtype {expected_type}"
#     736     )
#     737 return values
#
# MlflowException: dtype of input int64 does not match expected dtype float32
#
# During handling of the above exception, another exception occurred:
#
# MlflowException                           Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 loaded_model.predict(received_data)
#
# File c:\Users\ander\anaconda3\Lib\site-packages\mlflow\pyfunc\__init__.py:843, in PyFuncModel.predict(self, data, params)
#     841 if self.model_id:
#     842     context.update(model_id=self.model_id)
# --> 843 return self._predict(data, params)
#
# File c:\Users\ander\anaconda3\Lib\site-packages\mlflow\pyfunc\__init__.py:882, in PyFuncModel._predict(self, data, params)
#     880     params = _enforce_params_schema(params, self.params_schema)
#     881 else:
# --> 882     data, params = _validate_prediction_input(
#     883         data, params, self.input_schema, self.params_schema, self.loader_module
#     884     )
#     885     if (
#     886         isinstance(data, pandas.DataFrame)
#     887         and self.metadata._is_type_hint_from_example()
#     888         and self.input_example is not None
#     889     ):
#     890         data = _convert_dataframe_to_example_format(data, self.input_example)
#
# File c:\Users\ander\anaconda3\Lib\site-packages\mlflow\pyfunc\__init__.py:743, in _validate_prediction_input(data, params, input_schema, params_schema, flavor)
#     736         else:
#     737             # Include error in message for backwards compatibility
#     738             message = (
#     739                 f"Failed to enforce schema of data '{data}' "
#     740                 f"with schema '{input_schema}'. "
#     741                 f"Error: {e}"
#     742             )
# --> 743         raise MlflowException.invalid_parameter_value(message)
#     744 params = _enforce_params_schema(params, params_schema)
#     745 if HAS_PYSPARK and isinstance(data, SparkDataFrame):
#
# MlflowException: Failed to enforce schema of data '[[0 0 0 0]]' with schema '[Tensor('float32', (-1, 4))]'. Error: dtype of input int64 does not match expected dtype float32
